# %%
# Tanmay Vijay Jadhav (20121040)

# %%
import pandas as pd
import numpy as np

d = {'Name':(['Tom','James','Ricky','Vin','Steve','Smith','Jack','Lee','David','Gasper','Betin','Andres']),
    'Age':([25,26,25,23,30,29,23,34,40,30,51,46]),
     'Rating':([4.23,3.24,3.98,2.56,3.20,4.6,3.8,3.78,2.98,4.80,4.10,3.65])
    }

df = pd.DataFrame(d)
numeric_cols = df.select_dtypes(include=np.number)
print(df)
# Out:
#       Name  Age  Rating
# 0      Tom   25    4.23
# 1    James   26    3.24
# 2    Ricky   25    3.98
# 3      Vin   23    2.56
# 4    Steve   30    3.20
# 5    Smith   29    4.60
# 6     Jack   23    3.80
# 7      Lee   34    3.78
# 8    David   40    2.98
# 9   Gasper   30    4.80
# 10   Betin   51    4.10
# 11  Andres   46    3.65

# %%
print (df.sum())
# Out:
# Name      TomJamesRickyVinSteveSmithJackLeeDavidGasperBe...
# Age                                                     382
# Rating                                                44.92
# dtype: object

# %%
print(numeric_cols.sum(1))
# Out:
# 0     29.23
# 1     29.24
# 2     28.98
# 3     25.56
# 4     33.20
# 5     33.60
# 6     26.80
# 7     37.78
# 8     42.98
# 9     34.80
# 10    55.10
# 11    49.65
# dtype: float64

# %%
print(numeric_cols.mean())
# Out:
# Age       31.833333
# Rating     3.743333
# dtype: float64

# %%
print(numeric_cols.std())
# Out:
# Age       9.232682
# Rating    0.661628
# dtype: float64

# %%
print (df.describe())
# Out:
#              Age     Rating
# count  12.000000  12.000000
# mean   31.833333   3.743333
# std     9.232682   0.661628
# min    23.000000   2.560000
# 25%    25.000000   3.230000
# 50%    29.500000   3.790000
# 75%    35.500000   4.132500
# max    51.000000   4.800000

# %%
print (df.describe(include=['object']))
# Out:
#        Name
# count    12
# unique   12
# top     Tom
# freq      1

# %%
print (df.describe(include='all'))
# Out:
#        Name        Age     Rating
# count    12  12.000000  12.000000
# unique   12        NaN        NaN
# top     Tom        NaN        NaN
# freq      1        NaN        NaN
# mean    NaN  31.833333   3.743333
# std     NaN   9.232682   0.661628
# min     NaN  23.000000   2.560000
# 25%     NaN  25.000000   3.230000
# 50%     NaN  29.500000   3.790000
# 75%     NaN  35.500000   4.132500
# max     NaN  51.000000   4.800000

# %%
import pandas as pd
import numpy as np

mtcars = pd.read_csv("C:\\Users\\Admin\\Desktop\\DSBDA LAB\\mtcars.csv")

numeric_cols = mtcars.select_dtypes(include=np.number)
mtcars.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
print(numeric_cols.mean())
# Out:
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
mtcars = mtcars.rename(columns={'Unnamed: 0': 'model'})
mtcars.index = mtcars.model
mtcars.mean(axis=1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6204\527255881.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mtcars.mean(axis=1)
# model
# Mazda RX4              29.907273
# Mazda RX4 Wag          29.981364
# Datsun 710             23.598182
# Hornet 4 Drive         38.739545
# Hornet Sportabout      53.664545
# Valiant                35.049091
# Duster 360             59.720000
# Merc 240D              24.634545
# Merc 230               27.233636
# Merc 280               31.860000
# Merc 280C              31.787273
# Merc 450SE             46.430909
# Merc 450SL             46.500000
# Merc 450SLC            46.350000
# Cadillac Fleetwood     66.232727
# Lincoln Continental    66.058545
# Chrysler Imperial      65.972273
# Fiat 128               19.440909
# Honda Civic            17.742273
# ...

# %%
print(numeric_cols.median())
# Out:
# mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.710
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# dtype: float64

# %%
mtcars.mode()
# Out:
#                   model   mpg  cyl   disp     hp  drat    wt   qsec   vs   am  \
# 0           AMC Javelin  10.4  8.0  275.8  110.0  3.07  3.44  17.02  0.0  0.0
# 1    Cadillac Fleetwood  15.2  NaN    NaN  175.0  3.92   NaN  18.90  NaN  NaN
# 2            Camaro Z28  19.2  NaN    NaN  180.0   NaN   NaN    NaN  NaN  NaN
# 3     Chrysler Imperial  21.0  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 4            Datsun 710  21.4  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 5      Dodge Challenger  22.8  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 6            Duster 360  30.4  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 7          Ferrari Dino   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 8              Fiat 128   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 9             Fiat X1-9   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 10       Ford Pantera L   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# ...

# %%
import pandas as pd
from pandas.api.types import is_numeric_dtype
data= pd.read_csv("C:\\Users\\Admin\\Desktop\\DSBDA LAB\\iris.csv")
print(data)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
for col in data.columns:
    if is_numeric_dtype(data[col]):
        print('%s:'%(col))
        print('/t Mean= %.2f' % data[col].mean())
        print('/t Standard Deviation= %.2f'% data[col].std())
        print('/t Minimum= %.2f'% data[col].min())
        print('/t Maximum= %.2f'% data[col].max())
# Out:
# Id:
# /t Mean= 75.50
# /t Standard Deviation= 43.45
# /t Minimum= 1.00
# /t Maximum= 150.00
# SepalLengthCm:
# /t Mean= 5.84
# /t Standard Deviation= 0.83
# /t Minimum= 4.30
# /t Maximum= 7.90
# SepalWidthCm:
# /t Mean= 3.05
# /t Standard Deviation= 0.43
# /t Minimum= 2.00
# /t Maximum= 4.40
# PetalLengthCm:
# /t Mean= 3.76
# /t Standard Deviation= 1.76
# /t Minimum= 1.00
# /t Maximum= 6.90
# PetalWidthCm:
# /t Mean= 1.20
# /t Standard Deviation= 0.76
# /t Minimum= 0.10
# /t Maximum= 2.50

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
import numpy as np
numeric_cols = data.select_dtypes(include=np.number)
print(numeric_cols.median())
# Out:
# Id               75.50
# SepalLengthCm     5.80
# SepalWidthCm      3.00
# PetalLengthCm     4.35
# PetalWidthCm      1.30
# dtype: float64

# %%
import numpy as np
numeric_cols = data.select_dtypes(include=np.number)
print(numeric_cols.std())
# Out:
# Id               43.445368
# SepalLengthCm     0.828066
# SepalWidthCm      0.433594
# PetalLengthCm     1.764420
# PetalWidthCm      0.763161
# dtype: float64

# %%
#for categorical varible use 'object'
print(data.describe(include=['object']))
# Out:
#             Species
# count           150
# unique            3
# top     Iris-setosa
# freq             50

# %%
#for categorical plus numerical statistics use 'all'
print(data.describe(include='all'))
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.000000     150.000000    150.000000     150.000000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# mean     75.500000       5.843333      3.054000       3.758667      1.198667
# std      43.445368       0.828066      0.433594       1.764420      0.763161
# min       1.000000       4.300000      2.000000       1.000000      0.100000
# 25%      38.250000       5.100000      2.800000       1.600000      0.300000
# 50%      75.500000       5.800000      3.000000       4.350000      1.300000
# 75%     112.750000       6.400000      3.300000       5.100000      1.800000
# max     150.000000       7.900000      4.400000       6.900000      2.500000
#
#             Species
# count           150
# ...
